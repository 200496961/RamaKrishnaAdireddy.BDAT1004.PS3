# %% [markdown]
# # Question 1

# %% [markdown]
# Steps 1,2 and 3

# %%
#step 1
import pandas as pd
import numpy as np
import math

#step 2
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', delimiter='|')

#step3
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# Step 4

# %%
occupation_age_mean = users.groupby('occupation').agg({'age':['mean']})
print(occupation_age_mean)
# Out:
#                      age
#                     mean
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# Step 5

# %%
a=users[users['gender']=='M'].groupby('occupation').count()['gender']
b=users.groupby('occupation').count()['gender']
res=(a/b)*100
res.sort_values(ascending=False)
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# Name: gender, dtype: float64

# %% [markdown]
# Step 6

# %%
occupation_age_minmax = users.groupby('occupation').agg({'age':['min', 'max']})
print(occupation_age_minmax)
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %% [markdown]
# Step 7

# %%
users.groupby(['occupation','gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# Step 8

# %%
grp1=users[users['gender']=='M'].groupby('occupation').count()['gender']
grp2=users.groupby('occupation').count()['gender']
res1=pd.DataFrame((grp1/grp2)*100)
res1.columns=[('M')]
res #print(res)

grp3=users[users['gender']=='F'].groupby('occupation').count()['gender']
res2=pd.DataFrame((grp3/grp2)*100)
res2.columns=['F']
res2['M']=r['M']
res2  #print(res2)
# Out:
#                        F           M
# occupation
# administrator  45.569620   54.430380
# artist         46.428571   53.571429
# doctor               NaN  100.000000
# educator       27.368421   72.631579
# engineer        2.985075   97.014925
# entertainment  11.111111   88.888889
# executive       9.375000   90.625000
# healthcare     68.750000   31.250000
# homemaker      85.714286   14.285714
# lawyer         16.666667   83.333333
# librarian      56.862745   43.137255
# marketing      38.461538   61.538462
# none           44.444444   55.555556
# other          34.285714   65.714286
# programmer      9.090909   90.909091
# retired         7.142857   92.857143
# salesman       25.000000   75.000000
# scientist       9.677419   90.322581
# student        30.612245   69.387755
# technician      3.703704   96.296296
# writer         42.222222   57.777778

# %% [markdown]
# #  Question 2

# %% [markdown]
# Steps 1,2 and 3

# %%
#step 1
import pandas as pd
import numpy as np

#step 2
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

#step 3
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# Step 4

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step 5

# %%
print (euro12['Team'].count())
# Out:
# 16

# %% [markdown]
# Step 6

# %%
print(euro12.shape[1])
# Out:
# 35

# %% [markdown]
# Step 7

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8

# %%
discipline.sort_values(by=['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# Step 9

# %%
discipline.groupby('Team')['Yellow Cards'].mean()
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %% [markdown]
# Step 10

# %%
teams6 = euro12[(euro12.Goals>6)]
teams6['Team']
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# Step 11

# %%
teamG = euro12[euro12.Team.str[0]=='G']
teamG['Team']
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# Step 12

# %%
firstcol = euro12.iloc[:,0:7]
firstcol
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 13

# %%
exeplast = euro12.iloc[:,0:-3] #euro12.iloc[:,0,32]
exeplast
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14

# %%
shooting_accu = euro12.loc[euro12.Team.isin(['England','Italy','Russia']),'Shooting Accuracy']
shooting_accu
# Out:
# 3     50.0%
# 7     43.0%
# 12    22.5%
# Name: Shooting Accuracy, dtype: object

# %% [markdown]
# # Question 3

# %% [markdown]
# Step 1,2

# %%
import pandas as pd
import numpy as np


random1 = pd.Series(np.random.randint(1,5,100)) 
random2 = pd.Series(np.random.randint(1,4,100))
random3 = pd.Series(np.random.randint(10000,30001,100))

# %% [markdown]
# Step 3

# %%
dt=pd.concat([random1,random2,random3],axis=1)
datafrm=pd.DataFrame(data)
datafrm
# Out:
#     0  1      2
# 0   2  3  10283
# 1   1  3  25290
# 2   4  1  29754
# 3   2  3  17871
# 4   4  3  25665
# .. .. ..    ...
# 95  1  3  18495
# 96  2  2  29654
# 97  2  3  19088
# 98  4  1  27506
# 99  4  1  27903
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4

# %%
datafrm.rename(columns={0:'bedrs',1:'bathrs',2:'price_sqr_meter'},inplace=True)
datafrm
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       3            10283
# 1       1       3            25290
# 2       4       1            29754
# 3       2       3            17871
# 4       4       3            25665
# ..    ...     ...              ...
# 95      1       3            18495
# 96      2       2            29654
# 97      2       3            19088
# 98      4       1            27506
# 99      4       1            27903
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5

# %%
bigcolumn=pd.concat([random1,random2,random3])
bigcolumn
# Out:
# 0         2
# 1         1
# 2         4
# 3         2
# 4         4
#       ...
# 95    18495
# 96    29654
# 97    19088
# 98    27506
# 99    27903
# Length: 300, dtype: int32

# %% [markdown]
# Step 6

# %%
randomlist = random1
randomlist2 = randomlist.append(random2)
totalrandomlist = randomlist2.append(random3)
bigcolumn = pd.DataFrame({'Big Column': totalrandomlist})
bigcolumn
# Out:
#     Big Column
# 0            2
# 1            1
# 2            4
# 3            2
# 4            4
# ..         ...
# 95       18495
# 96       29654
# 97       19088
# 98       27506
# 99       27903
#
# [300 rows x 1 columns]

# %% [markdown]
# Step 7

# %% [markdown]
# # Question 4

# %% [markdown]
# Step 1,2

# %%
#step 1
import pandas as pd
import numpy as np
import datetime

data = pd.read_csv('C:\\Users\\ramki\\Desktop\\wind.csv')
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# Step 4

# %%
data["Datetime"] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))
data=data.drop(columns=["Yr","Mo","Dy"])
data["Datetime"].head()
# Out:
# 0   2061-01-01
# 1   2061-01-02
# 2   2061-01-03
# 3   2061-01-04
# 4   2061-01-05
# Name: Datetime, dtype: datetime64[ns]

# %%
data["str"]=data["Datetime"].astype(str).str.slice(0,4)
data["str"]=data["str"].astype(int)
data["str"]=data["str"].apply(lambda x: x-100 if x > 2021 else x)
data["DateTime"]=data["str"].astype(str) + data["Datetime"].astype(str).str.slice(4,10) 
data.drop (["Datetime","str"],axis=1,inplace=True)

# %%
data["DateTime"].astype("datetime64[ns]")
data.set_index("DateTime",inplace=True)

# %%
data.isnull().sum()
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
data.notnull().sum().sum()
# Out:
# 78857

# %%
data.mean().mean()
# Out:
# 10.222465245951712

# %%
a=pd.Series(data.min())
b=pd.Series(data.max())
c=pd.Series(data.mean())
sd=pd.Series(data.std())
l=pd.concat([a,b,c,sd],axis=1).transpose()
location_stats=pd.DataFrame(l)
location_stats
# Out:
#          RPT        VAL        ROS        KIL        SHA        BIR  \
# 0   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# 1  35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# 2  12.359979  10.640267  11.656396   6.298587  10.448923   7.085066
# 3   5.618805   5.268695   5.007805   3.600942   4.933988   3.967735
#
#          DUB        CLA        MUL        CLO        BEL        MAL
# 0   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# 1  30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# 2   9.793006   8.486601   8.490257   8.696705  13.110668  15.603129
# 3   4.978030   4.498299   4.165947   4.500488   5.829054   6.702178

# %%
x=pd.Series(data.min(axis=1),name="mean")
y=pd.Series(data.max(axis=1),name="max")
z=pd.Series(data.mean(axis=1),name="min")
sd=pd.Series(data.std(axis=1),name="std dev")
df=pd.merge(x,y,left_index=True,right_index=True)
df1=pd.merge(z,sd,left_index=True,right_index=True)
day_stats=df.join(df1)
day_stats
# Out:
#             mean    max        min   std dev
# DateTime
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# 1961-01-06  4.42  13.21   8.240000  2.998063
# 1961-01-07  4.96  14.29  10.385000  3.072114
# 1961-01-08  5.91  16.62  10.487500  3.547237
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6546 rows x 4 columns]

# %%
d=data.reset_index()
d["DateTime"]=d["DateTime"].apply(pd.to_datetime)
d.set_index("DateTime",inplace=True)
jan=d[d.index.month == 1]
jan.mean()
# Out:
# RPT    14.831609
# VAL    12.885389
# ROS    13.276275
# KIL     7.152477
# SHA    11.644467
# BIR     8.030561
# DUB    11.788336
# CLA     9.486962
# MUL     9.511501
# CLO    10.024069
# BEL    14.527848
# MAL    18.041826
# dtype: float64

# %%
print(d.resample('Y').mean())
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# DateTime
# 1961-12-31  12.207588  10.207206  11.282853  6.846441  10.742735  7.617147
# 1962-12-31  12.274779  10.150856  11.714365  6.964337  10.692265  7.415331
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
print(d.resample('M').mean())
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# DateTime
# 1961-01-31  14.506154  11.225385  12.960385  6.840000  10.509231   8.174231
# 1961-02-28  16.401923  15.037308  14.470000  9.242692  13.778077  10.884615
# 1961-03-31  10.660000  11.097407  10.420000  7.100741  10.265556   8.580000
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31  10.024643   8.495714  10.539286  5.992500   9.480357   6.633929
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
print(d.resample('W').mean())
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# DateTime
# 1961-01-08  12.316000  10.408000  10.050000   5.658000   8.506000   6.242000
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  12.100000   9.500000  11.681667   4.293333   8.966667   6.938333
# 1961-01-29  19.880000  14.846667  17.548333  11.916667  16.325000  14.016667
# 1961-02-05  16.827143  15.460000  12.618571   8.247143  13.361429   9.107143
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %%
y=d[d.index.year==1961]
y1=d.resample('W').mean().apply(lambda x: x.describe())
y1
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  939.000000  939.000000  939.000000  939.000000  939.000000  939.000000
# mean    12.356298   10.635444   11.652878    6.299636   10.449166    7.086745
# std      3.464961    3.371183    2.844036    2.182339    3.142446    2.552300
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 25%      9.867143    8.268571    9.626429    4.732857    8.252143    5.206429
# 50%     12.272857   10.468571   11.485714    6.132857   10.260000    6.932857
# 75%     14.524286   12.756429   13.446429    7.562143   12.604286    8.823571
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  939.000000  939.000000  939.000000  939.000000  939.000000  939.000000
# mean     9.792288    8.486521    8.490357    8.699941   13.110130   15.593725
# ...

# %% [markdown]
# # Question 5

# %%
#step 1
import pandas as pd
import numpy as np

#step 2 and 3
chipo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', delimiter = '\t')

#step 4
chipo[0:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 5
chipo.shape[0]
# Out:
# 4622

# %%
#step 6
chipo.shape[1]
# Out:
# 5

# %%
#step 7
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 8
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#step 9 and 10
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
#step 11
chipo.choice_description.value_counts().head(1)
# Out:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %%
#step 12
chipo['quantity'].sum()
# Out:
# 4972

# %%
#step 13
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:]))
chipo['item_price'].dtypes
# Out:
# dtype('float64')

# %%
#step 14
revenue = (chipo['quantity'] * chipo['item_price']).sum()
print(revenue)
# Out:
# 39237.02

# %%
#step 15
avg_revenue = chipo.order_id.value_counts().count()
avg_revenue
# Out:
# 1834

# %%
#step 16
revenue.sum()/avg_revenue
# Out:
# 21.39423118865867

# %%
#step 17
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# # Question 6

# %%
import matplotlib.pyplot as plt

fil=pd.read_csv('C:\\Users\\ramki\\Desktop\\us-marriages-divorces-1867-2014.csv')

fil.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
US_Year = pd.DataFrame(fil,columns=['Year'])
US_MDData = pd.DataFrame(fil,columns=['Marriages_per_1000','Divorces_per_1000']) 
fig, ax = plt.subplots()
for column in US_Data:
    ax.plot(fil['Year'], US_MDData[column])
ax.legend(US_MDData)
plt.xlabel("Year")
plt.ylabel("Per Capita")
plt.show()

# %% [markdown]
# # Question 7

# %%
import pandas as pd
import matplotlib.pyplot as plt

year1=pd.DataFrame(fil.loc[(fil['Year'] == 1900)])
year2=pd.DataFrame(fil.loc[(fil['Year'] == 1950)])
year3=pd.DataFrame(fil.loc[(fil['Year'] == 2000)])
final = pd.concat([year1, year2, year3])
final.plot(x="Year", y=["Marriages_per_1000", "Divorces_per_1000"], kind="bar")
plt.xlabel('Year')
plt.ylabel('Per Capita')
plt.show()

# %% [markdown]
# # Question 8

# %%
import pandas as pd
import matplotlib.pyplot as plt


Hollywood_actor_kill_count = pd.read_csv("C:\\Users\\ramki\\Desktop\\actor_kill_counts.csv")
Hollywood_actor_kill_count
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
Hollywood_actor_kill_count.sort_values(by=['Count'], inplace=True)
Actor_name = Hollywood_actor_kill_count['Actor']
Killcount = Hollywood_actor_kill_count['Count']
plt.barh(Actor_name, Killcount, align='center', alpha=0.5)
plt.xlabel('Kill count')
plt.ylabel('Actors Name')
plt.show()

# %% [markdown]
# # Question 9

# %%
import matplotlib.pyplot as plt
import pandas as pd

Roman_emperors = pd.read_csv("C:\\Users\\ramki\\Desktop\\roman-emperor-reigns.csv")
Roman_emperors
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
Roman_emperors_Data=pd.DataFrame(Roman_emperors.loc[(Roman_emperors['Cause_of_Death'] == "Assassinated")])
my_labels = Roman_emperors_Data['Emperor']
fig, ax = plt.subplots()
ax.pie(Roman_emperors_Data["Length_of_Reign"],labels=my_labels,autopct='%1.1f%%',textprops={'fontsize': 10})
fig = plt.gcf() 
fig.set_size_inches(12,12) 
plt.show()

# %% [markdown]
# # Question 10

# %%
import pandas as pd
import seaborn as sns


PHD_awards = pd.read_csv('C:\\Users\\ramki\\Desktop\\arcade-revenue-vs-cs-doctorates.csv')
PHD_awards
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
sns.scatterplot(x='Total Arcade Revenue (billions)', y='Computer Science Doctorates Awarded (US)', hue='Year', palette ='deep',data=PHD_awards)
# Out:
# <AxesSubplot:xlabel='Total Arcade Revenue (billions)', ylabel='Computer Science Doctorates Awarded (US)'>
